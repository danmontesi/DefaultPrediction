# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import catboost as ctb

pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Train Model, get best Hyperparameters and get Test Predictions
#
#
# This notebook can be used to train the model and get the predictions to the default condition of the samples given.
#
#
# Steps:
#
# 1. Load data previously preprocessed
# 2. Create model
# 3. Hyperparameter tuning
# 4. Test Prediction gathering

# %% [markdown]
# ### Import Data

# %%
cat_features = ['account_status', 'account_worst_status_0_3m', 'account_worst_status_12_24m', 'account_worst_status_3_6m', 'account_worst_status_6_12m', 'merchant_category', 'merchant_group', 'name_in_email', 'status_last_archived_0_24m', 'status_2nd_last_archived_0_24m', 'status_3rd_last_archived_0_24m', 'status_max_archived_0_6_months', 'status_max_archived_0_12_months', 'status_max_archived_0_24_months', 'worst_status_active_inv']
cols_to_drop = ['default', 'uuid']

train_df = pd.read_csv('../dataset/train.csv')
test_df = pd.read_csv('../dataset/test.csv')

train_df[cat_features] = train_df[cat_features].astype(str)
test_df[cat_features] = test_df[cat_features].astype(str)

# %% [markdown]
# ### Split Data

# %%
X_train = train_df.drop(cols_to_drop, axis=1)
y_train = train_df.default

# %% [markdown]
# ### Calculate Weight Classes for unbalanced data

# %%
pos_class_multiplier = len([x for x in y_train if x == 0])/len([x for x in y_train if x == 1])
round(pos_class_multiplier, 1)
# Out:
# 68.9

# %% [markdown]
# ### Catboost
# Catboost is a gradient boosting tree machine model algorithm. It can be used for regression, classification and ranking purpose. We will use it as a binary classification model.
#
# **Model properties**:
# - Being it a Gradient Boosting tree model, the data do not need to be normalized.
# - Also, being catboost able to handle categorical variables, we will let it learn the best representation to the categories, taking into account what we observed in our dataset in the exploration part (the cardinality of categories, etc.)
#
# **Metric choice**:
#
# Being this a default problem, we have to carefully decide for which metric to optimize, especially because the data has unbalanced classes. In Default prediction problems, we are interested in optimizing the metrics of recall (number of correctly classified defaults divided by the real defaults), hence to capture as many real defaults as possible.
#
# Of course, we would like to optimize as well the precision for the class(number of correctly classified defaults divided by the predicted defaults), but on a smaller extent.
# - Since we are interested on the **probability** of default as well, as primary metric to be optimized we wil use **AUC (Area Under the Curve).**
# - As second metric, however, we use the **Recall**. This means, that a very small improvements of AUC (less than 0.01% inferior to the best AUC), we will prioritize **Recall**.

# %%
prop = {
    'iterations': 20,
    'learning_rate': 0.2,
    'max_depth': 5
}

# prop_hyperparams_tuning =

# %%
model = ctb.CatBoostClassifier(**prop)

model.fit(X_train, y_train, cat_features=[X_train.columns.tolist().index(x) for x in cat_features],)
# Out:
# 0:	learn: 0.3608925	total: 85.3ms	remaining: 1.62s
# 1:	learn: 0.2110240	total: 113ms	remaining: 1.01s
# 2:	learn: 0.1402432	total: 139ms	remaining: 787ms
# 3:	learn: 0.1025079	total: 163ms	remaining: 652ms
# 4:	learn: 0.0857504	total: 187ms	remaining: 560ms
# 5:	learn: 0.0771777	total: 208ms	remaining: 484ms
# 6:	learn: 0.0709211	total: 230ms	remaining: 428ms
# 7:	learn: 0.0673333	total: 257ms	remaining: 385ms
# 8:	learn: 0.0639148	total: 279ms	remaining: 340ms
# 9:	learn: 0.0619321	total: 307ms	remaining: 307ms
# 10:	learn: 0.0606679	total: 335ms	remaining: 274ms
# 11:	learn: 0.0595902	total: 363ms	remaining: 242ms
# 12:	learn: 0.0590011	total: 390ms	remaining: 210ms
# 13:	learn: 0.0585283	total: 412ms	remaining: 177ms
# 14:	learn: 0.0581004	total: 436ms	remaining: 145ms
# 15:	learn: 0.0577268	total: 459ms	remaining: 115ms
# 16:	learn: 0.0573642	total: 481ms	remaining: 84.9ms
# 17:	learn: 0.0567881	total: 505ms	remaining: 56.1ms
# 18:	learn: 0.0562943	total: 536ms	remaining: 28.2ms
# 19:	learn: 0.0559334	total: 562ms	remaining: 0us

# %%
y_preds = model.predict(test_df.drop(cols_to_drop, axis=1))
y_proba = model.predict_proba(test_df.drop(cols_to_drop, axis=1))

# %%
[x for x in y_preds if x ==1]
# Out:
# [1.0, 1.0, 1.0]

# %% [markdown]
# ### Hyperparameter Tuning
#
# In order to reduce Overfitting, we need to perform Hyperparameter Tuning.
# For this task, we decide to implement a Random Validator class iterating over a distribution of values over certain parameters. The random validator is based on a **Cross-Validation over N=10 folds.**
#
# Below we create the class able to run Hyperparameter Tuning of the model

# %%
import gc
from random import randint
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import recall_score, make_scorer, roc_auc_score, f1_score, classification_report
from sklearn.datasets import make_classification

class RandomValidator:
    """
    searches the parameter space randomly.
    params can be specified directly in the recommender class that I want to validate 
    (check out one that has those already specified)
    convention: range in tuple -> consider all the possible value in between
                range in list  -> consider just the values in the list
    """

    def __init__(self, train_df, labels, fixed_params, searching_params, num_folds=10, num_iterations=10, export=True, cat_features=[], granularity=1):
        self.train_df = train_df
        self.labels = labels
        self.fixed_params = fixed_params
        self.searching_params = searching_params
        self.num_iterations = num_iterations
        self.num_folds = num_folds
        self.export = export
        self.cat_features = cat_features
        self.granularity = granularity
        self.best_params = None
        
        # initialize crossvalidation
        
        # create dataset
        
        
    
    def update_parameter(self, param, value):
        print('Not implemented yet')
        
    def run_cv_iteration(self, model, skf):
        sum_auc = 0
        sum_recall = 0
        sum_f1 = 0
        
        for train_index, test_index in skf.split(self.train_df, self.labels):
            X_train, X_test = self.train_df.iloc[train_index], self.train_df.iloc[test_index]
            y_train, y_test = self.labels[train_index], self.labels[test_index]
            
            # train & measure

            model.fit(X_train, y_train, cat_features=[X_train.columns.tolist().index(x) for x in cat_features], verbose = 0)
            
            # Predict & eval
            y_pred = model.predict(X_test)
            y_proba = model.predict_proba(X_test)[:, 1]
            
            auc = roc_auc_score(y_test, y_proba)
            recall = recall_score(y_test, y_pred)
            f1 = f1_score(y_test, y_pred, average='weighted')
            
            sum_auc += auc
            sum_recall += recall
            sum_f1 += f1
            
            # print(classification_report(y_test, y_pred))
        
        auc_avg = sum_auc/self.num_folds
        recall_avg = sum_recall/self.num_folds
        f1_avg = sum_f1/self.num_folds
        
        print('### FINAL CV average SCORES ###')
        print('AUC avg:', round(auc_avg, 3))
        print('recall at fold:', round(recall_avg, 3))
        print('f1 avg:', round(f1_avg, 3))
        
        return auc_avg, recall_avg
        
    def sample(self, obj):
        if type(obj) == tuple:
            low_bound = obj[0]
            upp_bound = obj[1]
            rand_numb = randint(0, self.granularity)
            step = (upp_bound - low_bound)/self.granularity
            return low_bound + step*rand_numb
        elif type(obj) == list:
            return obj[randint(0, len(obj)-1)] 


    def get_best_params(self):
        return self.best_params
        
        
    def run(self):
        
        # prepare the cross-validation procedure
        skf = StratifiedKFold(n_splits=self.num_folds, shuffle=False, random_state=42)
        
        dict_results = {'params': [], 'auc': [], 'recall': []}
        
        for i in range(self.num_iterations):
            
            # sample a random parameter from the dictionary
            sampled_params = {}
            for key, value in self.searching_params.items():
                sampled_params[key] = self.sample(value)

            params_dict = {**self.fixed_params, **sampled_params}
            
            print('Validating with params_dict', params_dict)
            
            model = ctb.CatBoostClassifier(**params_dict)
            
            auc_avg, recall_avg = self.run_cv_iteration(model, skf)
            
            dict_results['params'].append(params_dict)
            dict_results['auc'].append(auc_avg)
            dict_results['recall'].append(recall_avg)
            
            if (auc_avg >= 0.999 * np.max(dict_results['auc'])):
                # get idx of list with max auc
                idxs_max_auc = [i for i in range(len(dict_results['auc'])) if auc_avg >= 0.999*dict_results['auc'][i]]
                
                recalls_lists = [dict_results['recall'][i] for i in idxs_max_auc]
                
                if recall_avg == np.max(recalls_lists):
                    print('#### Found new best configuration #### ')
                    self.best_params = params_dict
            
            
            #if self.export != None:
            #    self.export.check_if_export(score, params_dict)

# %% [markdown]
# We declare the parameters to be searched, and the fixed parameters

# %%
searching_params = {
    'max_depth': [7], 
    'reg_lambda': [96], 
    'one_hot_max_size': [35], 
    'model_size_reg': [1], 
    'max_ctr_complexity': [3],
    'learning_rate': [0.015, 0.02, 0.025, 0.03, 0.035],
    'iterations': [200, 225, 250, 275, 300, 350, 400]
    #'simple_ctr': ['Counter', 'Buckets'],
    #'combinations_ctr': ['Counter', 'Buckets'] 
}

fixed_params = {
    'class_weights': (1, pos_class_multiplier)
}

# %%
ctb_cv_validator = RandomValidator(X_train, y_train, fixed_params = fixed_params, searching_params = searching_params, num_folds=5, num_iterations=3, granularity=10)

ctb_cv_validator.run()
# Out:
# /Users/danielemontesi/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# Validating with params_dict {'class_weights': (1, 68.85714285714286), 'max_depth': 7, 'reg_lambda': 96, 'one_hot_max_size': 35, 'model_size_reg': 1, 'max_ctr_complexity': 3, 'learning_rate': 0.035, 'iterations': 350}
# ### FINAL CV average SCORES ###
# AUC avg: 0.91
# recall at fold: 0.816
# f1 avg: 0.896
# #### Found new best configuration ####
# Validating with params_dict {'class_weights': (1, 68.85714285714286), 'max_depth': 7, 'reg_lambda': 96, 'one_hot_max_size': 35, 'model_size_reg': 1, 'max_ctr_complexity': 3, 'learning_rate': 0.035, 'iterations': 400}
# ### FINAL CV average SCORES ###
# AUC avg: 0.909
# recall at fold: 0.808
# f1 avg: 0.9
# Validating with params_dict {'class_weights': (1, 68.85714285714286), 'max_depth': 7, 'reg_lambda': 96, 'one_hot_max_size': 35, 'model_size_reg': 1, 'max_ctr_complexity': 3, 'learning_rate': 0.03, 'iterations': 400}
# ### FINAL CV average SCORES ###
# AUC avg: 0.91
# recall at fold: 0.819
# f1 avg: 0.895
# #### Found new best configuration ####

# %% [markdown]
# ### Train and save final model
#
# After performing Hyperparameter tuning, we observe that the best iteration has been performed over the hyperparameters:
#     {
#         learning_rate: 0.035,
#         iterations: 250,
#         max_depth: 7
#     }
#
# Thus, we are able to train our final model fitting the entire training dataset and we store the dataset as a pkl file ready for the deployment

# %%
# Fit the best model configuration found
best_params = ctb_cv_validator.get_best_params()

final_model = ctb.CatBoostClassifier(**best_params)

final_model.fit(X_train, y_train, cat_features=[X_train.columns.tolist().index(x) for x in cat_features],)
# Out:
# 0:	learn: 0.6776589	total: 34.1ms	remaining: 13.6s
# 1:	learn: 0.6619712	total: 64ms	remaining: 12.7s
# 2:	learn: 0.6486929	total: 93.1ms	remaining: 12.3s
# 3:	learn: 0.6349551	total: 119ms	remaining: 11.8s
# 4:	learn: 0.6238422	total: 148ms	remaining: 11.7s
# 5:	learn: 0.6117459	total: 180ms	remaining: 11.8s
# 6:	learn: 0.6026692	total: 206ms	remaining: 11.6s
# 7:	learn: 0.5931476	total: 239ms	remaining: 11.7s
# 8:	learn: 0.5842677	total: 272ms	remaining: 11.8s
# 9:	learn: 0.5757203	total: 306ms	remaining: 11.9s
# 10:	learn: 0.5676024	total: 337ms	remaining: 11.9s
# 11:	learn: 0.5591030	total: 367ms	remaining: 11.9s
# 12:	learn: 0.5519810	total: 397ms	remaining: 11.8s
# 13:	learn: 0.5454695	total: 429ms	remaining: 11.8s
# 14:	learn: 0.5390338	total: 462ms	remaining: 11.9s
# 15:	learn: 0.5341243	total: 494ms	remaining: 11.9s
# 16:	learn: 0.5283867	total: 523ms	remaining: 11.8s
# 17:	learn: 0.5232529	total: 553ms	remaining: 11.7s
# 18:	learn: 0.5163119	total: 584ms	remaining: 11.7s
# 19:	learn: 0.5117854	total: 613ms	remaining: 11.6s
# 20:	learn: 0.5059583	total: 647ms	remaining: 11.7s
# 21:	learn: 0.5003134	total: 684ms	remaining: 11.7s
# 22:	learn: 0.4960506	total: 719ms	remaining: 11.8s
# 23:	learn: 0.4912866	total: 751ms	remaining: 11.8s
# 24:	learn: 0.4868999	total: 782ms	remaining: 11.7s
# 25:	learn: 0.4827651	total: 813ms	remaining: 11.7s
# 26:	learn: 0.4787864	total: 841ms	remaining: 11.6s
# 27:	learn: 0.4751135	total: 872ms	remaining: 11.6s
# 28:	learn: 0.4719225	total: 905ms	remaining: 11.6s
# 29:	learn: 0.4686507	total: 936ms	remaining: 11.5s
# 30:	learn: 0.4655691	total: 966ms	remaining: 11.5s
# 31:	learn: 0.4633894	total: 997ms	remaining: 11.5s
# 32:	learn: 0.4604089	total: 1.03s	remaining: 11.5s
# 33:	learn: 0.4579439	total: 1.06s	remaining: 11.4s
# 34:	learn: 0.4547765	total: 1.09s	remaining: 11.4s
# 35:	learn: 0.4526551	total: 1.13s	remaining: 11.4s
# 36:	learn: 0.4502055	total: 1.16s	remaining: 11.4s
# 37:	learn: 0.4476686	total: 1.19s	remaining: 11.4s
# 38:	learn: 0.4452279	total: 1.23s	remaining: 11.4s
# 39:	learn: 0.4434771	total: 1.26s	remaining: 11.3s
# 40:	learn: 0.4415987	total: 1.29s	remaining: 11.3s
# 41:	learn: 0.4394335	total: 1.32s	remaining: 11.2s
# 42:	learn: 0.4375389	total: 1.35s	remaining: 11.2s
# 43:	learn: 0.4356764	total: 1.38s	remaining: 11.1s
# 44:	learn: 0.4340914	total: 1.4s	remaining: 11.1s
# 45:	learn: 0.4318199	total: 1.44s	remaining: 11s
# 46:	learn: 0.4303535	total: 1.46s	remaining: 11s
# 47:	learn: 0.4285114	total: 1.49s	remaining: 10.9s
# 48:	learn: 0.4273371	total: 1.52s	remaining: 10.9s
# 49:	learn: 0.4255751	total: 1.55s	remaining: 10.9s
# 50:	learn: 0.4245127	total: 1.58s	remaining: 10.8s
# 51:	learn: 0.4230537	total: 1.61s	remaining: 10.8s
# 52:	learn: 0.4213025	total: 1.64s	remaining: 10.7s
# 53:	learn: 0.4199744	total: 1.67s	remaining: 10.7s
# 54:	learn: 0.4188269	total: 1.7s	remaining: 10.7s
# 55:	learn: 0.4174487	total: 1.73s	remaining: 10.6s
# 56:	learn: 0.4168276	total: 1.75s	remaining: 10.6s
# 57:	learn: 0.4159106	total: 1.78s	remaining: 10.5s
# 58:	learn: 0.4148443	total: 1.81s	remaining: 10.5s
# 59:	learn: 0.4139869	total: 1.84s	remaining: 10.4s
# 60:	learn: 0.4133141	total: 1.86s	remaining: 10.3s
# 61:	learn: 0.4124302	total: 1.89s	remaining: 10.3s
# 62:	learn: 0.4110931	total: 1.92s	remaining: 10.2s
# 63:	learn: 0.4098137	total: 1.95s	remaining: 10.2s
# 64:	learn: 0.4087499	total: 1.98s	remaining: 10.2s
# 65:	learn: 0.4078212	total: 2s	remaining: 10.1s
# 66:	learn: 0.4070451	total: 2.04s	remaining: 10.1s
# 67:	learn: 0.4061112	total: 2.07s	remaining: 10.1s
# 68:	learn: 0.4052466	total: 2.1s	remaining: 10.1s
# 69:	learn: 0.4039673	total: 2.13s	remaining: 10s
# 70:	learn: 0.4028129	total: 2.16s	remaining: 10s
# 71:	learn: 0.4016593	total: 2.19s	remaining: 9.99s
# 72:	learn: 0.4007791	total: 2.23s	remaining: 9.97s
# 73:	learn: 0.3999815	total: 2.25s	remaining: 9.94s
# 74:	learn: 0.3986572	total: 2.29s	remaining: 9.91s
# 75:	learn: 0.3976803	total: 2.32s	remaining: 9.89s
# 76:	learn: 0.3967563	total: 2.35s	remaining: 9.87s
# 77:	learn: 0.3961405	total: 2.38s	remaining: 9.84s
# 78:	learn: 0.3952186	total: 2.42s	remaining: 9.81s
# 79:	learn: 0.3947241	total: 2.44s	remaining: 9.78s
# 80:	learn: 0.3941698	total: 2.47s	remaining: 9.75s
# 81:	learn: 0.3933866	total: 2.5s	remaining: 9.71s
# 82:	learn: 0.3927347	total: 2.53s	remaining: 9.67s
# 83:	learn: 0.3922097	total: 2.56s	remaining: 9.63s
# 84:	learn: 0.3917304	total: 2.59s	remaining: 9.6s
# 85:	learn: 0.3907206	total: 2.62s	remaining: 9.58s
# 86:	learn: 0.3899094	total: 2.66s	remaining: 9.56s
# 87:	learn: 0.3892085	total: 2.69s	remaining: 9.53s
# 88:	learn: 0.3886675	total: 2.72s	remaining: 9.5s
# 89:	learn: 0.3879023	total: 2.75s	remaining: 9.47s
# 90:	learn: 0.3870571	total: 2.78s	remaining: 9.45s
# 91:	learn: 0.3863421	total: 2.82s	remaining: 9.43s
# 92:	learn: 0.3856937	total: 2.85s	remaining: 9.41s
# 93:	learn: 0.3850370	total: 2.88s	remaining: 9.38s
# 94:	learn: 0.3845828	total: 2.91s	remaining: 9.34s
# 95:	learn: 0.3837771	total: 2.94s	remaining: 9.31s
# 96:	learn: 0.3832391	total: 2.97s	remaining: 9.28s
# 97:	learn: 0.3825883	total: 3s	remaining: 9.25s
# 98:	learn: 0.3821211	total: 3.03s	remaining: 9.22s
# 99:	learn: 0.3812741	total: 3.07s	remaining: 9.2s
# 100:	learn: 0.3804230	total: 3.1s	remaining: 9.17s
# 101:	learn: 0.3800341	total: 3.13s	remaining: 9.13s
# 102:	learn: 0.3794310	total: 3.15s	remaining: 9.1s
# 103:	learn: 0.3791963	total: 3.17s	remaining: 9.04s
# 104:	learn: 0.3786046	total: 3.2s	remaining: 9s
# 105:	learn: 0.3777456	total: 3.23s	remaining: 8.97s
# 106:	learn: 0.3774134	total: 3.26s	remaining: 8.94s
# 107:	learn: 0.3770547	total: 3.29s	remaining: 8.91s
# 108:	learn: 0.3765663	total: 3.33s	remaining: 8.88s
# 109:	learn: 0.3762473	total: 3.36s	remaining: 8.85s
# 110:	learn: 0.3758212	total: 3.39s	remaining: 8.82s
# 111:	learn: 0.3751981	total: 3.41s	remaining: 8.78s
# 112:	learn: 0.3745077	total: 3.44s	remaining: 8.75s
# 113:	learn: 0.3736799	total: 3.47s	remaining: 8.72s
# 114:	learn: 0.3732154	total: 3.5s	remaining: 8.68s
# 115:	learn: 0.3727973	total: 3.54s	remaining: 8.66s
# 116:	learn: 0.3724859	total: 3.56s	remaining: 8.62s
# 117:	learn: 0.3718137	total: 3.6s	remaining: 8.59s
# 118:	learn: 0.3712933	total: 3.63s	remaining: 8.57s
# 119:	learn: 0.3709694	total: 3.66s	remaining: 8.54s
# 120:	learn: 0.3703824	total: 3.69s	remaining: 8.51s
# 121:	learn: 0.3701319	total: 3.72s	remaining: 8.48s
# 122:	learn: 0.3696742	total: 3.75s	remaining: 8.46s
# 123:	learn: 0.3693461	total: 3.79s	remaining: 8.43s
# 124:	learn: 0.3685723	total: 3.82s	remaining: 8.4s
# 125:	learn: 0.3680396	total: 3.85s	remaining: 8.36s
# 126:	learn: 0.3675933	total: 3.88s	remaining: 8.33s
# 127:	learn: 0.3669860	total: 3.91s	remaining: 8.3s
# 128:	learn: 0.3665247	total: 3.94s	remaining: 8.28s
# 129:	learn: 0.3664067	total: 3.96s	remaining: 8.22s
# 130:	learn: 0.3661585	total: 3.98s	remaining: 8.18s
# 131:	learn: 0.3658200	total: 4.01s	remaining: 8.14s
# 132:	learn: 0.3653079	total: 4.04s	remaining: 8.11s
# 133:	learn: 0.3648697	total: 4.07s	remaining: 8.08s
# 134:	learn: 0.3645806	total: 4.1s	remaining: 8.04s
# 135:	learn: 0.3640944	total: 4.13s	remaining: 8.01s
# 136:	learn: 0.3634099	total: 4.17s	remaining: 8s
# 137:	learn: 0.3628592	total: 4.2s	remaining: 7.97s
# 138:	learn: 0.3626091	total: 4.22s	remaining: 7.93s
# 139:	learn: 0.3623376	total: 4.25s	remaining: 7.9s
# 140:	learn: 0.3620451	total: 4.28s	remaining: 7.86s
# 141:	learn: 0.3616748	total: 4.31s	remaining: 7.83s
# 142:	learn: 0.3612236	total: 4.34s	remaining: 7.8s
# 143:	learn: 0.3609422	total: 4.37s	remaining: 7.77s
# 144:	learn: 0.3606149	total: 4.4s	remaining: 7.73s
# 145:	learn: 0.3603051	total: 4.43s	remaining: 7.7s
# 146:	learn: 0.3596415	total: 4.46s	remaining: 7.68s
# 147:	learn: 0.3589686	total: 4.49s	remaining: 7.65s
# 148:	learn: 0.3587498	total: 4.52s	remaining: 7.62s
# 149:	learn: 0.3583945	total: 4.55s	remaining: 7.59s
# 150:	learn: 0.3582129	total: 4.58s	remaining: 7.56s
# 151:	learn: 0.3577800	total: 4.62s	remaining: 7.53s
# 152:	learn: 0.3575833	total: 4.64s	remaining: 7.49s
# 153:	learn: 0.3573384	total: 4.67s	remaining: 7.46s
# 154:	learn: 0.3569062	total: 4.7s	remaining: 7.43s
# 155:	learn: 0.3565791	total: 4.73s	remaining: 7.41s
# 156:	learn: 0.3563204	total: 4.76s	remaining: 7.38s
# 157:	learn: 0.3560354	total: 4.8s	remaining: 7.35s
# 158:	learn: 0.3557085	total: 4.83s	remaining: 7.32s
# 159:	learn: 0.3556457	total: 4.85s	remaining: 7.27s
# 160:	learn: 0.3552368	total: 4.88s	remaining: 7.25s
# 161:	learn: 0.3550035	total: 4.91s	remaining: 7.21s
# 162:	learn: 0.3547055	total: 4.94s	remaining: 7.18s
# 163:	learn: 0.3543225	total: 4.96s	remaining: 7.14s
# 164:	learn: 0.3538851	total: 5s	remaining: 7.12s
# 165:	learn: 0.3532898	total: 5.03s	remaining: 7.09s
# 166:	learn: 0.3529576	total: 5.06s	remaining: 7.06s
# 167:	learn: 0.3526801	total: 5.09s	remaining: 7.03s
# 168:	learn: 0.3523101	total: 5.12s	remaining: 7s
# 169:	learn: 0.3521711	total: 5.15s	remaining: 6.96s
# 170:	learn: 0.3518436	total: 5.18s	remaining: 6.94s
# 171:	learn: 0.3517113	total: 5.21s	remaining: 6.9s
# 172:	learn: 0.3512645	total: 5.24s	remaining: 6.88s
# 173:	learn: 0.3510171	total: 5.27s	remaining: 6.85s
# 174:	learn: 0.3508730	total: 5.3s	remaining: 6.81s
# 175:	learn: 0.3507751	total: 5.32s	remaining: 6.78s
# 176:	learn: 0.3503695	total: 5.36s	remaining: 6.75s
# 177:	learn: 0.3500557	total: 5.38s	remaining: 6.71s
# 178:	learn: 0.3498229	total: 5.41s	remaining: 6.68s
# 179:	learn: 0.3494684	total: 5.45s	remaining: 6.66s
# 180:	learn: 0.3492766	total: 5.48s	remaining: 6.63s
# 181:	learn: 0.3490437	total: 5.51s	remaining: 6.6s
# 182:	learn: 0.3486843	total: 5.54s	remaining: 6.57s
# 183:	learn: 0.3483478	total: 5.57s	remaining: 6.54s
# 184:	learn: 0.3481567	total: 5.59s	remaining: 6.5s
# 185:	learn: 0.3479143	total: 5.62s	remaining: 6.47s
# 186:	learn: 0.3478160	total: 5.65s	remaining: 6.44s
# 187:	learn: 0.3475631	total: 5.69s	remaining: 6.41s
# 188:	learn: 0.3472458	total: 5.71s	remaining: 6.38s
# 189:	learn: 0.3470328	total: 5.74s	remaining: 6.35s
# 190:	learn: 0.3467093	total: 5.77s	remaining: 6.32s
# 191:	learn: 0.3465010	total: 5.8s	remaining: 6.29s
# 192:	learn: 0.3463452	total: 5.83s	remaining: 6.25s
# 193:	learn: 0.3461388	total: 5.86s	remaining: 6.22s
# 194:	learn: 0.3458956	total: 5.89s	remaining: 6.19s
# 195:	learn: 0.3456971	total: 5.92s	remaining: 6.16s
# 196:	learn: 0.3455502	total: 5.95s	remaining: 6.13s
# 197:	learn: 0.3453959	total: 5.98s	remaining: 6.1s
# 198:	learn: 0.3451704	total: 6.01s	remaining: 6.07s
# 199:	learn: 0.3449366	total: 6.04s	remaining: 6.04s
# 200:	learn: 0.3445664	total: 6.08s	remaining: 6.01s
# 201:	learn: 0.3443453	total: 6.1s	remaining: 5.98s
# 202:	learn: 0.3440126	total: 6.13s	remaining: 5.95s
# 203:	learn: 0.3438542	total: 6.16s	remaining: 5.92s
# 204:	learn: 0.3436584	total: 6.19s	remaining: 5.89s
# 205:	learn: 0.3435076	total: 6.22s	remaining: 5.86s
# 206:	learn: 0.3432078	total: 6.25s	remaining: 5.83s
# 207:	learn: 0.3429072	total: 6.29s	remaining: 5.81s
# 208:	learn: 0.3426816	total: 6.32s	remaining: 5.78s
# 209:	learn: 0.3425340	total: 6.35s	remaining: 5.74s
# 210:	learn: 0.3422033	total: 6.38s	remaining: 5.71s
# 211:	learn: 0.3419228	total: 6.41s	remaining: 5.68s
# 212:	learn: 0.3417361	total: 6.44s	remaining: 5.65s
# 213:	learn: 0.3413997	total: 6.47s	remaining: 5.62s
# 214:	learn: 0.3411971	total: 6.51s	remaining: 5.6s
# 215:	learn: 0.3410920	total: 6.54s	remaining: 5.57s
# 216:	learn: 0.3410131	total: 6.57s	remaining: 5.54s
# 217:	learn: 0.3408385	total: 6.6s	remaining: 5.51s
# 218:	learn: 0.3404604	total: 6.63s	remaining: 5.48s
# 219:	learn: 0.3403294	total: 6.66s	remaining: 5.45s
# 220:	learn: 0.3398855	total: 6.69s	remaining: 5.42s
# 221:	learn: 0.3397122	total: 6.72s	remaining: 5.39s
# 222:	learn: 0.3395798	total: 6.75s	remaining: 5.36s
# 223:	learn: 0.3394170	total: 6.79s	remaining: 5.33s
# 224:	learn: 0.3392819	total: 6.81s	remaining: 5.3s
# 225:	learn: 0.3388186	total: 6.84s	remaining: 5.27s
# 226:	learn: 0.3387793	total: 6.86s	remaining: 5.23s
# 227:	learn: 0.3385794	total: 6.89s	remaining: 5.2s
# 228:	learn: 0.3383217	total: 6.92s	remaining: 5.17s
# 229:	learn: 0.3381693	total: 6.95s	remaining: 5.14s
# 230:	learn: 0.3379072	total: 6.98s	remaining: 5.11s
# 231:	learn: 0.3376953	total: 7.01s	remaining: 5.08s
# 232:	learn: 0.3375050	total: 7.04s	remaining: 5.05s
# 233:	learn: 0.3374501	total: 7.07s	remaining: 5.01s
# 234:	learn: 0.3371749	total: 7.1s	remaining: 4.99s
# 235:	learn: 0.3369078	total: 7.13s	remaining: 4.96s
# 236:	learn: 0.3366973	total: 7.17s	remaining: 4.93s
# 237:	learn: 0.3366299	total: 7.2s	remaining: 4.9s
# 238:	learn: 0.3364565	total: 7.23s	remaining: 4.87s
# 239:	learn: 0.3362090	total: 7.26s	remaining: 4.84s
# 240:	learn: 0.3360572	total: 7.29s	remaining: 4.81s
# 241:	learn: 0.3357923	total: 7.32s	remaining: 4.78s
# 242:	learn: 0.3356197	total: 7.35s	remaining: 4.75s
# 243:	learn: 0.3354146	total: 7.38s	remaining: 4.71s
# 244:	learn: 0.3352661	total: 7.41s	remaining: 4.68s
# 245:	learn: 0.3349179	total: 7.44s	remaining: 4.66s
# 246:	learn: 0.3348862	total: 7.46s	remaining: 4.62s
# 247:	learn: 0.3347371	total: 7.49s	remaining: 4.59s
# 248:	learn: 0.3344211	total: 7.53s	remaining: 4.56s
# 249:	learn: 0.3342814	total: 7.55s	remaining: 4.53s
# 250:	learn: 0.3340683	total: 7.59s	remaining: 4.5s
# 251:	learn: 0.3339677	total: 7.61s	remaining: 4.47s
# 252:	learn: 0.3338560	total: 7.65s	remaining: 4.44s
# 253:	learn: 0.3336284	total: 7.67s	remaining: 4.41s
# 254:	learn: 0.3333217	total: 7.7s	remaining: 4.38s
# 255:	learn: 0.3332114	total: 7.73s	remaining: 4.35s
# 256:	learn: 0.3331243	total: 7.76s	remaining: 4.32s
# 257:	learn: 0.3329420	total: 7.79s	remaining: 4.28s
# 258:	learn: 0.3327114	total: 7.82s	remaining: 4.25s
# 259:	learn: 0.3325571	total: 7.84s	remaining: 4.22s
# 260:	learn: 0.3322430	total: 7.88s	remaining: 4.2s
# 261:	learn: 0.3321631	total: 7.91s	remaining: 4.16s
# 262:	learn: 0.3320364	total: 7.93s	remaining: 4.13s
# 263:	learn: 0.3319496	total: 7.96s	remaining: 4.1s
# 264:	learn: 0.3318320	total: 8s	remaining: 4.07s
# 265:	learn: 0.3316876	total: 8.03s	remaining: 4.04s
# 266:	learn: 0.3315059	total: 8.06s	remaining: 4.01s
# 267:	learn: 0.3314318	total: 8.08s	remaining: 3.98s
# 268:	learn: 0.3313015	total: 8.11s	remaining: 3.95s
# 269:	learn: 0.3311361	total: 8.14s	remaining: 3.92s
# 270:	learn: 0.3310364	total: 8.17s	remaining: 3.89s
# 271:	learn: 0.3309465	total: 8.2s	remaining: 3.86s
# 272:	learn: 0.3308993	total: 8.23s	remaining: 3.83s
# 273:	learn: 0.3306165	total: 8.26s	remaining: 3.8s
# 274:	learn: 0.3305574	total: 8.29s	remaining: 3.77s
# 275:	learn: 0.3304185	total: 8.32s	remaining: 3.74s
# 276:	learn: 0.3302630	total: 8.35s	remaining: 3.71s
# 277:	learn: 0.3298854	total: 8.38s	remaining: 3.68s
# 278:	learn: 0.3297738	total: 8.41s	remaining: 3.65s
# 279:	learn: 0.3295643	total: 8.44s	remaining: 3.62s
# 280:	learn: 0.3293317	total: 8.47s	remaining: 3.59s
# 281:	learn: 0.3290427	total: 8.51s	remaining: 3.56s
# 282:	learn: 0.3287709	total: 8.54s	remaining: 3.53s
# 283:	learn: 0.3285486	total: 8.57s	remaining: 3.5s
# 284:	learn: 0.3281829	total: 8.6s	remaining: 3.47s
# 285:	learn: 0.3280080	total: 8.64s	remaining: 3.44s
# 286:	learn: 0.3278887	total: 8.67s	remaining: 3.41s
# 287:	learn: 0.3277348	total: 8.7s	remaining: 3.38s
# 288:	learn: 0.3276533	total: 8.72s	remaining: 3.35s
# 289:	learn: 0.3273592	total: 8.75s	remaining: 3.32s
# 290:	learn: 0.3272617	total: 8.78s	remaining: 3.29s
# 291:	learn: 0.3269801	total: 8.81s	remaining: 3.26s
# 292:	learn: 0.3267239	total: 8.85s	remaining: 3.23s
# 293:	learn: 0.3264212	total: 8.88s	remaining: 3.2s
# 294:	learn: 0.3263744	total: 8.9s	remaining: 3.17s
# 295:	learn: 0.3263281	total: 8.93s	remaining: 3.14s
# 296:	learn: 0.3262894	total: 8.95s	remaining: 3.1s
# 297:	learn: 0.3261573	total: 8.97s	remaining: 3.07s
# 298:	learn: 0.3261004	total: 9s	remaining: 3.04s
# 299:	learn: 0.3260281	total: 9.02s	remaining: 3.01s
# 300:	learn: 0.3257621	total: 9.05s	remaining: 2.98s
# 301:	learn: 0.3252714	total: 9.08s	remaining: 2.95s
# 302:	learn: 0.3251736	total: 9.11s	remaining: 2.92s
# 303:	learn: 0.3249499	total: 9.14s	remaining: 2.89s
# 304:	learn: 0.3247492	total: 9.17s	remaining: 2.86s
# 305:	learn: 0.3246210	total: 9.2s	remaining: 2.83s
# 306:	learn: 0.3245758	total: 9.23s	remaining: 2.79s
# 307:	learn: 0.3245522	total: 9.25s	remaining: 2.76s
# 308:	learn: 0.3244064	total: 9.28s	remaining: 2.73s
# 309:	learn: 0.3242414	total: 9.31s	remaining: 2.7s
# 310:	learn: 0.3237289	total: 9.34s	remaining: 2.67s
# 311:	learn: 0.3235065	total: 9.37s	remaining: 2.64s
# 312:	learn: 0.3234051	total: 9.4s	remaining: 2.61s
# 313:	learn: 0.3231404	total: 9.43s	remaining: 2.58s
# 314:	learn: 0.3229438	total: 9.46s	remaining: 2.55s
# 315:	learn: 0.3228340	total: 9.49s	remaining: 2.52s
# 316:	learn: 0.3225609	total: 9.52s	remaining: 2.49s
# 317:	learn: 0.3222400	total: 9.55s	remaining: 2.46s
# 318:	learn: 0.3220087	total: 9.59s	remaining: 2.43s
# 319:	learn: 0.3218086	total: 9.62s	remaining: 2.4s
# 320:	learn: 0.3216507	total: 9.64s	remaining: 2.37s
# 321:	learn: 0.3216034	total: 9.67s	remaining: 2.34s
# 322:	learn: 0.3213224	total: 9.7s	remaining: 2.31s
# 323:	learn: 0.3210840	total: 9.73s	remaining: 2.28s
# 324:	learn: 0.3206615	total: 9.77s	remaining: 2.25s
# 325:	learn: 0.3206116	total: 9.79s	remaining: 2.22s
# 326:	learn: 0.3204958	total: 9.82s	remaining: 2.19s
# 327:	learn: 0.3202772	total: 9.85s	remaining: 2.16s
# 328:	learn: 0.3199944	total: 9.88s	remaining: 2.13s
# 329:	learn: 0.3198252	total: 9.91s	remaining: 2.1s
# 330:	learn: 0.3196497	total: 9.94s	remaining: 2.07s
# 331:	learn: 0.3196469	total: 9.96s	remaining: 2.04s
# 332:	learn: 0.3193371	total: 9.99s	remaining: 2.01s
# 333:	learn: 0.3188650	total: 10s	remaining: 1.98s
# 334:	learn: 0.3185912	total: 10.1s	remaining: 1.95s
# 335:	learn: 0.3184781	total: 10.1s	remaining: 1.92s
# 336:	learn: 0.3182470	total: 10.1s	remaining: 1.89s
# 337:	learn: 0.3179318	total: 10.1s	remaining: 1.86s
# 338:	learn: 0.3177060	total: 10.2s	remaining: 1.83s
# 339:	learn: 0.3173543	total: 10.2s	remaining: 1.8s
# 340:	learn: 0.3170735	total: 10.2s	remaining: 1.77s
# 341:	learn: 0.3168249	total: 10.3s	remaining: 1.74s
# 342:	learn: 0.3166285	total: 10.3s	remaining: 1.71s
# 343:	learn: 0.3164182	total: 10.3s	remaining: 1.68s
# 344:	learn: 0.3161501	total: 10.4s	remaining: 1.65s
# 345:	learn: 0.3156999	total: 10.4s	remaining: 1.62s
# 346:	learn: 0.3155028	total: 10.4s	remaining: 1.59s
# 347:	learn: 0.3153130	total: 10.4s	remaining: 1.56s
# 348:	learn: 0.3151041	total: 10.5s	remaining: 1.53s
# 349:	learn: 0.3150718	total: 10.5s	remaining: 1.5s
# 350:	learn: 0.3149092	total: 10.5s	remaining: 1.47s
# 351:	learn: 0.3148442	total: 10.6s	remaining: 1.44s
# 352:	learn: 0.3145843	total: 10.6s	remaining: 1.41s
# 353:	learn: 0.3143997	total: 10.6s	remaining: 1.38s
# 354:	learn: 0.3143059	total: 10.6s	remaining: 1.35s
# 355:	learn: 0.3140338	total: 10.7s	remaining: 1.32s
# 356:	learn: 0.3138405	total: 10.7s	remaining: 1.29s
# 357:	learn: 0.3137674	total: 10.7s	remaining: 1.26s
# 358:	learn: 0.3134986	total: 10.7s	remaining: 1.23s
# 359:	learn: 0.3134083	total: 10.8s	remaining: 1.2s
# 360:	learn: 0.3133977	total: 10.8s	remaining: 1.17s
# 361:	learn: 0.3131579	total: 10.8s	remaining: 1.14s
# 362:	learn: 0.3129639	total: 10.9s	remaining: 1.11s
# 363:	learn: 0.3128314	total: 10.9s	remaining: 1.08s
# 364:	learn: 0.3126989	total: 10.9s	remaining: 1.05s
# 365:	learn: 0.3123472	total: 10.9s	remaining: 1.02s
# 366:	learn: 0.3120746	total: 11s	remaining: 987ms
# 367:	learn: 0.3119523	total: 11s	remaining: 957ms
# 368:	learn: 0.3118734	total: 11s	remaining: 927ms
# 369:	learn: 0.3117834	total: 11.1s	remaining: 897ms
# 370:	learn: 0.3114882	total: 11.1s	remaining: 868ms
# 371:	learn: 0.3112475	total: 11.1s	remaining: 838ms
# 372:	learn: 0.3110457	total: 11.2s	remaining: 808ms
# 373:	learn: 0.3110189	total: 11.2s	remaining: 778ms
# 374:	learn: 0.3107999	total: 11.2s	remaining: 748ms
# 375:	learn: 0.3105648	total: 11.3s	remaining: 718ms
# 376:	learn: 0.3103394	total: 11.3s	remaining: 688ms
# 377:	learn: 0.3102315	total: 11.3s	remaining: 658ms
# 378:	learn: 0.3100980	total: 11.3s	remaining: 628ms
# 379:	learn: 0.3100860	total: 11.4s	remaining: 598ms
# 380:	learn: 0.3100456	total: 11.4s	remaining: 568ms
# 381:	learn: 0.3097457	total: 11.4s	remaining: 538ms
# 382:	learn: 0.3095754	total: 11.4s	remaining: 508ms
# 383:	learn: 0.3093711	total: 11.5s	remaining: 478ms
# 384:	learn: 0.3090894	total: 11.5s	remaining: 448ms
# 385:	learn: 0.3089983	total: 11.5s	remaining: 418ms
# 386:	learn: 0.3087558	total: 11.6s	remaining: 388ms
# 387:	learn: 0.3085603	total: 11.6s	remaining: 358ms
# 388:	learn: 0.3084004	total: 11.6s	remaining: 328ms
# 389:	learn: 0.3081781	total: 11.6s	remaining: 299ms
# 390:	learn: 0.3079596	total: 11.7s	remaining: 269ms
# 391:	learn: 0.3078091	total: 11.7s	remaining: 239ms
# 392:	learn: 0.3075979	total: 11.7s	remaining: 209ms
# 393:	learn: 0.3073648	total: 11.8s	remaining: 179ms
# 394:	learn: 0.3072554	total: 11.8s	remaining: 149ms
# 395:	learn: 0.3071069	total: 11.8s	remaining: 119ms
# 396:	learn: 0.3069592	total: 11.8s	remaining: 89.5ms
# 397:	learn: 0.3066191	total: 11.9s	remaining: 59.7ms
# 398:	learn: 0.3064531	total: 11.9s	remaining: 29.9ms
# 399:	learn: 0.3061571	total: 11.9s	remaining: 0us

# %%
# Get prediction probabilities of the test entries
test_preds = model.predict_proba(test_df[X_train.columns])[:, 1]

prediction_df = pd.DataFrame({'uuid': test_df.uuid, 'pd': test_preds})

# save prediction file
prediction_df.to_csv('../output/predictions.csv', index=False)

# display predictions
prediction_df.head()
# Out:
#                                    uuid        pd
# 0  6f6e6c6a-2081-4e6b-8eb3-4fd89b54b2d7  0.005663
# 1  f6f6d9f3-ef2b-4329-a388-c6a687f27e70  0.021215
# 2  e9c39869-1bc5-4375-b627-a2df70b445ea  0.002246
# 3  6beb88a3-9641-4381-beb6-c9a208664dd0  0.012482
# 4  bb89b735-72fe-42a4-ba06-d63be0f4ca36  0.050293

# %% [markdown]
# ### Save Model as a Pickle file

# %%
import pickle

with open('final_model.pkl', 'wb') as f:
    pickle.dump(final_model, f)

with open('final_model.pkl', 'rb') as f:
    model_loaded = pickle.load(f)
    
model_loaded

# %%
model_loaded.get_params()
# Out:
# {'iterations': 400,
#  'learning_rate': 0.03,
#  'model_size_reg': 1,
#  'max_ctr_complexity': 3,
#  'class_weights': (1, 68.85714285714286),
#  'one_hot_max_size': 35,
#  'max_depth': 7,
#  'reg_lambda': 96}
